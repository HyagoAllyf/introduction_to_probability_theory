# %% [markdown]
# # Inferência Estatística: Teorema Central do Limite
#
# ## Amostra aleatória

# %% [markdown]
# import numpy as np
# import matplotlib.pyplot as plt
# mu = 0
# sigma = 1
# n = 3
# m = 4
# for i in range(0,n):
#     X = np.random.normal(mu, sigma, m)
#     print(f'Amostra {i}: {X}')

# %% [markdown]
# aplicação do teorema:

# %%
# distribuição normal
import numpy as np
import matplotlib.pyplot as plt

vn = []
vmean = []
mu = 0
std = 1
for n in np.arange(1,100000,10):
    X = np.random.normal(mu, std, n)
    vmean.append(np.mean(X))
    vn.append(n)
plt.figure(figsize=(8,6))
plt.plot(vn, vmean, '-', color='black')
plt.axhline(y=mu, color='r', linestyle='-')
plt.xlabel(r'$n$', fontsize=20)
plt.ylabel(r'$\bar{X}$', fontsize=20)

plt.show(True)

# %%
vn = []
vmean = []
mu = 2
std = 1
for n in np.arange(1,10000,10):
    X = np.random.exponential(mu, n)
    vmean.append(np.mean(X))
    vn.append(n)
plt.figure(figsize=(8,6))
plt.plot(vn, vmean, '-', color='black')
plt.axhline(y=mu, color='r', linestyle='-')
plt.xlabel(r'$n$', fontsize=20)
plt.ylabel(r'$\bar{X}$', fontsize=20)

plt.show(True)
